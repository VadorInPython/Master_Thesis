# %% [markdown]
# # Package Installation

# %%
#pip install zenodo-get

# %% [markdown]
# # Imports

# %%
import zenodo_get
import numpy as np

# %% [markdown]
# # Zenodo dataset acquisition

# %%
#!zenodo_get -a U47cUVes1cb5XIIu9cI2hHPXgnqs3fWmmmEjNHKXd2BWPFg65rarcExYIuSD 18808026

# %%
sample_das = np.load(r'080000.npy')
sample_das
# Out:
# array([[  -9,   25,   -7, ...,   38,    1,  -35],
#        [  15,  -42,  -42, ...,   29,   17,   86],
#        [ -13,    2,    7, ...,   36,   45,    5],
#        ...,
#        [  15,  -64,  -27, ...,   10,  -12,  -34],
#        [  16,  -67, -115, ...,   14,  -41,  -85],
#        [ -43,   61,   56, ...,    2,  -24,  -60]],
#       shape=(4000, 3917), dtype=int16)

# %%
sample_das_1 = np.load(r'080010.npy')
sample_das_1
# Out:
# array([[ -6, -35, -42, ...,   9, -30, -53],
#        [ 25, -22, -34, ...,   7,  -2, -52],
#        [-70,  57,  81, ...,  12, -16, -42],
#        ...,
#        [ 25, -30, -59, ...,  -3, -31, -16],
#        [-32,   6,   2, ..., -27,  17, -14],
#        [-45,  50,  60, ...,  17,  14,  40]],
#       shape=(4000, 3917), dtype=int16)
