# %% [markdown]
# # Package Installation

# %%
#pip install zenodo-get

# %% [markdown]
# # Imports

# %%
import zenodo_get

# %% [markdown]
# # Zenodo dataset acquisition

# %%
zenodo_get -a U47cUVes1cb5XIIu9cI2hHPXgnqs3fWmmmEjNHKXd2BWPFg65rarcExYIuSD 18808030
# Out:
#   Cell In[8], line 1
#     zenodo_get -a U47cUVes1cb5XIIu9cI2hHPXgnqs3fWmmmEjNHKXd2BWPFg65rarcExYIuSD 18808030
#                   ^
# SyntaxError: invalid syntax
